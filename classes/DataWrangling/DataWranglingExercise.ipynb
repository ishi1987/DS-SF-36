# %% [markdown]
#   # Datetime Package
#   &copy; QuantSprout

# %% [markdown]
# #### Bonus: Try converting strings to datetime objects and datetime objects back to strings.  What are some interesting datetime formats you can find in the documentation?

# %%
import os

import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

# %%
df = pd.read_csv('Storms.csv.gz')
# Out:
# STATE__       902297
# BGN_DATE      902297
# BGN_TIME      902297
# TIME_ZONE     902297
# COUNTY        902297
#                ...
# LONGITUDE     902297
# LATITUDE_E    902257
# LONGITUDE_    902297
# REMARKS       614864
# REFNUM        902297
# Length: 37, dtype: int64

# %%
df.count()
# Out:
# STATE__       902297
# BGN_DATE      902297
# BGN_TIME      902297
# TIME_ZONE     902297
# COUNTY        902297
#                ...
# LONGITUDE     902297
# LATITUDE_E    902257
# LONGITUDE_    902297
# REMARKS       614864
# REFNUM        902297
# Length: 37, dtype: int64

# %%
#Getting a feel of the data to see what the data looks like
df
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 902292     56.0  11/30/2011 0:00:00  10:30:00 PM       MST     7.0    ...
# 902293     30.0  11/10/2011 0:00:00  02:48:00 PM       MST     9.0    ...
# 902294      2.0   11/8/2011 0:00:00  02:58:00 PM       AKS   213.0    ...
# 902295      2.0   11/9/2011 0:00:00  10:21:00 AM       AKS   202.0    ...
# 902296      1.0  11/28/2011 0:00:00  08:00:00 PM       CST     6.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# ...

# %%
#To check what are the the columns in the dataframe
df.columns
#Trying to look at rows that contain na's
pd.isnull(df)
# Out:
#         STATE__  BGN_DATE  BGN_TIME  TIME_ZONE  COUNTY   ...    LONGITUDE  \
# 0         False     False     False      False   False   ...        False
# 1         False     False     False      False   False   ...        False
# 2         False     False     False      False   False   ...        False
# 3         False     False     False      False   False   ...        False
# 4         False     False     False      False   False   ...        False
# ...         ...       ...       ...        ...     ...   ...          ...
# 902292    False     False     False      False   False   ...        False
# 902293    False     False     False      False   False   ...        False
# 902294    False     False     False      False   False   ...        False
# 902295    False     False     False      False   False   ...        False
# 902296    False     False     False      False   False   ...        False
#
#         LATITUDE_E  LONGITUDE_  REMARKS  REFNUM
# ...

# %%
df.describe()
# Out:
#              STATE__         COUNTY      BGN_RANGE  COUNTY_END  COUNTYENDN  \
# count  902297.000000  902297.000000  902297.000000    902297.0         0.0
# mean       31.200958     100.642905       1.483889         0.0         NaN
# std        16.570178     107.276509       5.481574         0.0         NaN
# min         1.000000       0.000000       0.000000         0.0         NaN
# 25%        19.000000      31.000000       0.000000         0.0         NaN
# 50%        30.000000      75.000000       0.000000         0.0         NaN
# 75%        45.000000     131.000000       1.000000         0.0         NaN
# max        95.000000     873.000000    3749.000000         0.0         NaN
#
#            ...             LATITUDE      LONGITUDE     LATITUDE_E  \
# count      ...        902250.000000  902297.000000  902257.000000
# mean       ...          2874.942950    6939.538350    1451.611545
# std        ...          1657.648801    3958.062506    1858.727873
# ...

# %%
#drop all columns that contain na
df.dropna(axis=1)
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 902292     56.0  11/30/2011 0:00:00  10:30:00 PM       MST     7.0    ...
# 902293     30.0  11/10/2011 0:00:00  02:48:00 PM       MST     9.0    ...
# 902294      2.0   11/8/2011 0:00:00  02:58:00 PM       AKS   213.0    ...
# 902295      2.0   11/9/2011 0:00:00  10:21:00 AM       AKS   202.0    ...
# 902296      1.0  11/28/2011 0:00:00  08:00:00 PM       CST     6.0    ...
#
#        PROPDMG CROPDMG  LONGITUDE  LONGITUDE_    REFNUM
# ...

# %%
df['ZONENAMES']
# Out:
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
#                                 ...
# 902292    OWL CREEK & BRIDGER MOUNTAINS - OWL CREEK & BR...
# 902293    NORTH ROCKY MOUNTAIN FRONT - NORTH ROCKY MOUNT...
# 902294    ST LAWRENCE IS. BERING STRAIT - ST LAWRENCE IS...
# 902295        NORTHERN ARCTIC COAST - NORTHERN ARCTIC COAST
# 902296                                    MADISON - MADISON
# Name: ZONENAMES, Length: 902297, dtype: object

# %%
#finding the total number of null values in the dataframe
df.isnull()
# Out:
#         STATE__  BGN_DATE  BGN_TIME  TIME_ZONE  COUNTY   ...    LONGITUDE  \
# 0         False     False     False      False   False   ...        False
# 1         False     False     False      False   False   ...        False
# 2         False     False     False      False   False   ...        False
# 3         False     False     False      False   False   ...        False
# 4         False     False     False      False   False   ...        False
# ...         ...       ...       ...        ...     ...   ...          ...
# 902292    False     False     False      False   False   ...        False
# 902293    False     False     False      False   False   ...        False
# 902294    False     False     False      False   False   ...        False
# 902295    False     False     False      False   False   ...        False
# 902296    False     False     False      False   False   ...        False
#
#         LATITUDE_E  LONGITUDE_  REMARKS  REFNUM
# ...

# %%
df.count()
# Out:
# STATE__       902297
# BGN_DATE      902297
# BGN_TIME      902297
# TIME_ZONE     902297
# COUNTY        902297
#                ...
# LONGITUDE     902297
# LATITUDE_E    902257
# LONGITUDE_    902297
# REMARKS       614864
# REFNUM        902297
# Length: 37, dtype: int64

# %%
#dropping all the rows where the values are all null
df.dropna()
# Out:
# Empty DataFrame
# Columns: [STATE__, BGN_DATE, BGN_TIME, TIME_ZONE, COUNTY, COUNTYNAME, STATE, EVTYPE, BGN_RANGE, BGN_AZI, BGN_LOCATI, END_DATE, END_TIME, COUNTY_END, COUNTYENDN, END_RANGE, END_AZI, END_LOCATI, LENGTH, WIDTH, F, MAG, FATALITIES, INJURIES, PROPDMG, PROPDMGEXP, CROPDMG, CROPDMGEXP, WFO, STATEOFFIC, ZONENAMES, LATITUDE, LONGITUDE, LATITUDE_E, LONGITUDE_, REMARKS, REFNUM]
# Index: []
#
# [0 rows x 37 columns]

# %%
#Counting the number of rows and columns
df.count()
# Out:
# STATE__       902297
# BGN_DATE      902297
# BGN_TIME      902297
# TIME_ZONE     902297
# COUNTY        902297
#                ...
# LONGITUDE     902297
# LATITUDE_E    902257
# LONGITUDE_    902297
# REMARKS       614864
# REFNUM        902297
# Length: 37, dtype: int64

# %%
#Trying to see if there are outliers in the data or not. The mean and the 50% of some of the columns is far away
df.describe()
# Out:
#              STATE__         COUNTY      BGN_RANGE  COUNTY_END  COUNTYENDN  \
# count  902297.000000  902297.000000  902297.000000    902297.0         0.0
# mean       31.200958     100.642905       1.483889         0.0         NaN
# std        16.570178     107.276509       5.481574         0.0         NaN
# min         1.000000       0.000000       0.000000         0.0         NaN
# 25%        19.000000      31.000000       0.000000         0.0         NaN
# 50%        30.000000      75.000000       0.000000         0.0         NaN
# 75%        45.000000     131.000000       1.000000         0.0         NaN
# max        95.000000     873.000000    3749.000000         0.0         NaN
#
#            ...             LATITUDE      LONGITUDE     LATITUDE_E  \
# count      ...        902250.000000  902297.000000  902257.000000
# mean       ...          2874.942950    6939.538350    1451.611545
# std        ...          1657.648801    3958.062506    1858.727873
# ...

# %%
#plotting some boxplots to see the distribution of data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11cada690>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125067a50>]], dtype=object)

# %%
df.describe()
# Out:
#              STATE__         COUNTY      BGN_RANGE  COUNTY_END  COUNTYENDN  \
# count  902297.000000  902297.000000  902297.000000    902297.0         0.0
# mean       31.200958     100.642905       1.483889         0.0         NaN
# std        16.570178     107.276509       5.481574         0.0         NaN
# min         1.000000       0.000000       0.000000         0.0         NaN
# 25%        19.000000      31.000000       0.000000         0.0         NaN
# 50%        30.000000      75.000000       0.000000         0.0         NaN
# 75%        45.000000     131.000000       1.000000         0.0         NaN
# max        95.000000     873.000000    3749.000000         0.0         NaN
#
#            ...             LATITUDE      LONGITUDE     LATITUDE_E  \
# count      ...        902250.000000  902297.000000  902257.000000
# mean       ...          2874.942950    6939.538350    1451.611545
# std        ...          1657.648801    3958.062506    1858.727873
# ...

# %%
#noticed that county end was 0 overall
df.COUNTY_END.unique()
# Out:
# array([ 0.])

# %%
df.corr()
# Out:
#              STATE__    COUNTY  BGN_RANGE  COUNTY_END  COUNTYENDN    ...     \
# STATE__     1.000000  0.306231   0.045905         NaN         NaN    ...
# COUNTY      0.306231  1.000000   0.054419         NaN         NaN    ...
# BGN_RANGE   0.045905  0.054419   1.000000         NaN         NaN    ...
# COUNTY_END       NaN       NaN        NaN         NaN         NaN    ...
# COUNTYENDN       NaN       NaN        NaN         NaN         NaN    ...
# ...              ...       ...        ...         ...         ...    ...
# LATITUDE   -0.006642  0.034407   0.071263         NaN         NaN    ...
# LONGITUDE  -0.024199  0.097044   0.089530         NaN         NaN    ...
# LATITUDE_E -0.029509  0.007791   0.111696         NaN         NaN    ...
# LONGITUDE_ -0.039056  0.032864   0.123731         NaN         NaN    ...
# REFNUM      0.090742  0.017981   0.115187         NaN         NaN    ...
#
#             LATITUDE  LONGITUDE  LATITUDE_E  LONGITUDE_    REFNUM
# ...

# %%
#noticed that county_end and countyendn are same throughout
#notice that ev_types have been officially stated in the data documentation
#For now, to clean the dataset we should drop county_end and countyendn
df = df.drop('COUNTY_END', 1)
df = df.drop('COUNTYENDN', 1)

# %%
df.columns.value_counts()
# Out:
# ZONENAMES     1
# LONGITUDE     1
# END_TIME      1
# FATALITIES    1
# STATE         1
#              ..
# BGN_TIME      1
# LATITUDE_E    1
# END_RANGE     1
# INJURIES      1
# LONGITUDE_    1
# Length: 35, dtype: int64

# %%
#finding out official events
df.columns
# Out:
# Index([u'STATE__', u'BGN_DATE', u'BGN_TIME', u'TIME_ZONE', u'COUNTY',
#        u'COUNTYNAME', u'STATE', u'EVTYPE', u'BGN_RANGE', u'BGN_AZI',
#        u'BGN_LOCATI', u'END_DATE', u'END_TIME', u'END_RANGE', u'END_AZI',
#        u'END_LOCATI', u'LENGTH', u'WIDTH', u'F', u'MAG', u'FATALITIES',
#        u'INJURIES', u'PROPDMG', u'PROPDMGEXP', u'CROPDMG', u'CROPDMGEXP',
#        u'WFO', u'STATEOFFIC', u'ZONENAMES', u'LATITUDE', u'LONGITUDE',
#        u'LATITUDE_E', u'LONGITUDE_', u'REMARKS', u'REFNUM'],
#       dtype='object')

# %%
df.hist(by="EVTYPE",bins=10)
# Out:
# /Users/issingh/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6097: UserWarning: 2D hist input should be nsamples x nvariables;
#  this looks transposed (shape is 2 x 17)
#   '(shape is %d x %d)' % inp.shape[::-1])
# /Users/issingh/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6097: UserWarning: 2D hist input should be nsamples x nvariables;
#  this looks transposed (shape is 1 x 17)
#   '(shape is %d x %d)' % inp.shape[::-1])
# /Users/issingh/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6097: UserWarning: 2D hist input should be nsamples x nvariables;
#  this looks transposed (shape is 3 x 17)
#   '(shape is %d x %d)' % inp.shape[::-1])
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x121105050>,
# ...
# ...
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x15ff372d0>]], dtype=object)

# %%
df.EVTYPE.hist()
# Out:
# HAIL                              288661
# TSTM WIND                         219940
# THUNDERSTORM WIND                  82563
# TORNADO                            60652
# FLASH FLOOD                        54277
#                                    ...
# EXCESSIVE                              1
# LANDSLUMP                              1
# NORTHERN LIGHTS                        1
# HURRICANE EMILY                        1
# THUNDERSTORM WINDS/FLASH FLOOD         1
# Name: EVTYPE, Length: 985, dtype: int64

# %%
valseries = df.EVTYPE.value_counts()

# %%
valseries
# Out:
# HAIL                              288661
# TSTM WIND                         219940
# THUNDERSTORM WIND                  82563
# TORNADO                            60652
# FLASH FLOOD                        54277
#                                    ...
# EXCESSIVE                              1
# LANDSLUMP                              1
# NORTHERN LIGHTS                        1
# HURRICANE EMILY                        1
# THUNDERSTORM WINDS/FLASH FLOOD         1
# Name: EVTYPE, Length: 985, dtype: int64

# %%
#Trying to find the point at which we should put the evtype count cut off on
#the least occuring evtypes need to be excluded
valseries.axes
valseries = valseries.cumsum()
valseries.max()
valseries.add

# %%
valseries
# Out:
# HAIL                                    288661
# TSTM WIND                              1085923
# THUNDERSTORM WIND                      2474349
# TORNADO                                4514591
# FLASH FLOOD                            7260926
#                                       ...
# EXCESSIVE                         430650377779
# LANDSLUMP                         431532159043
# NORTHERN LIGHTS                   432414842602
# HURRICANE EMILY                   433298428457
# THUNDERSTORM WINDS/FLASH FLOOD    434182916609
# Name: EVTYPE, Length: 985, dtype: int64

# %%
valseries.axes
# Out:
# [Index([u'HAIL', u'TSTM WIND', u'THUNDERSTORM WIND', u'TORNADO', u'FLASH FLOOD',
#         u'FLOOD', u'THUNDERSTORM WINDS', u'HIGH WIND', u'LIGHTNING',
#         u'HEAVY SNOW',
#         ...
#         u'Summary August 7', u'TUNDERSTORM WIND', u'THUNDERSTORM WIND 59',
#         u'THUNDERSTORM WIND 56', u'THUNDERSTORM WIND 52', u'EXCESSIVE',
#         u'LANDSLUMP', u'NORTHERN LIGHTS', u'HURRICANE EMILY',
#         u'THUNDERSTORM WINDS/FLASH FLOOD'],
#        dtype='object', length=985)]

# %%
valseries.hist()

# %%
dfexp
# Out:
#                        EVTYPE  EVTYPE
#    HIGH SURF ADVISORY       1       1
#  COASTAL FLOOD              1       1
#  FLASH FLOOD                1       1
#  LIGHTNING                  1       1
#  TSTM WIND                  1       4
# ...                       ...     ...
# blowing snow                1       2
# coastal flooding            1       2
# gradient wind               1       2
# small hail                  1       5
# wet micoburst               1       1
#
# [985 rows x 2 columns]

# %%
dfexp.plot(kind = 'scatter', x = 'EVTYPE', y = 'EVTYPE', s = 100, figsize = (8, 8))

# %%
df['C'] = df.ix[::-1, 'A'].cumsum()[::-1]

# %%
exp1 = df.EVTYPE.value_counts()

# %%
lstofOnes = exp1[exp1==1].index.values

# %%
len(lstofOnes)
# Out:
# 489

# %%
lstofOnes
# Out:
# array(['BITTER WIND CHILL', 'Thunderstorm Wind', 'THUNDERSTORM WINDS 61',
#        'THUNDERSTORM WINDS 62', 'COASTAL  FLOODING/EROSION',
#        'HEAT WAVE DROUGHT', 'HIGH WINDS 82', 'Summary of June 30',
#        'BLIZZARD/WINTER STORM', 'DAM FAILURE', 'DUST STORM/HIGH WINDS',
#        'THUNDERSTORM WINDS 60', 'EXTREMELY WET', 'ICE STORM/FLASH FLOOD',
#        'HIGH WIND/WIND CHILL/BLIZZARD', 'HIGH WIND AND SEAS',
#        'SMALL STREAM URBAN FLOOD', 'SMALL STREAM', 'COLD AIR TORNADO',
#        'HIGH WINDS/COASTAL FLOOD', 'SNOWSTORM', 'FUNNEL CLOUD.',
#        'HEAVY SNOW/SLEET', 'DRIEST MONTH', 'LIGHTNING DAMAGE',
#        'THUNDERSTORM WIND.', 'LIGHTNING INJURY', 'DRYNESS', 'TSTMW',
#        'FLOODING/HEAVY RAIN', 'THUNDERSTORM DAMAGE TO', 'RECORD WARM',
#        'WARM DRY CONDITIONS', 'Mild and Dry Pattern',
#        'THUNDERESTORM WINDS', 'FLASH FLOOD LANDSLIDES', 'SEVERE COLD',
#        'TSTM WIND 50', 'RECORD HIGH TEMPERATURES',
# ...

# %%
dffinal = df[df.EVTYPE.isin(lstofOnes) == False]

# %%
dffinal.EVTYPE.unique()
# Out:
# array(['TORNADO', 'TSTM WIND', 'HAIL', 'FREEZING RAIN', 'SNOW', 'SNOW/ICE',
#        'WINTER STORM', 'THUNDERSTORM WINDS', 'RECORD COLD',
#        'HURRICANE ERIN', 'HURRICANE OPAL', 'HEAVY RAIN', 'LIGHTNING',
#        'THUNDERSTORM WIND', 'DENSE FOG', 'RIP CURRENT', 'FLASH FLOOD',
#        'FLASH FLOODING', 'HIGH WINDS', 'FUNNEL CLOUD', 'TORNADO F0',
#        'THUNDERSTORM WINDS LIGHTNING', 'THUNDERSTORM WINDS/HAIL', 'HEAT',
#        'WIND', 'LIGHTING', 'HEAVY RAINS', 'FUNNEL', 'WALL CLOUD',
#        'FLOODING', 'THUNDERSTORM WINDS HAIL', 'FLOOD', 'COLD',
#        'THUNDERSTORM', 'WATERSPOUT', 'EXTREME COLD', 'HIGH WIND',
#        'BLIZZARD', 'WIND CHILL', 'HIGH WIND/BLIZZARD', 'RIVER FLOOD',
#        'HEAVY SNOW', 'FREEZE', 'COASTAL FLOOD', 'HIGH WIND AND HIGH TIDES',
#        'HIGH TIDES', 'RECORD HIGH TEMPERATURE', 'RECORD HIGH', 'ICE STORM',
#        'RECORD LOW', 'AVALANCHE', 'MARINE MISHAP', 'HIGH WIND/HEAVY SNOW',
# ...

# %%
dffinal.groupby('EVTYPE').EVTYPE.nunique()
# Out:
# EVTYPE
#  TSTM WIND              1
# ABNORMAL WARMTH         1
# ABNORMALLY DRY          1
# ACCUMULATED SNOWFALL    1
# AGRICULTURAL FREEZE     1
#                        ..
# Wintry mix              1
# blowing snow            1
# coastal flooding        1
# gradient wind           1
# small hail              1
# Name: EVTYPE, Length: 496, dtype: int64

# %%
dffinal.describe()
# Out:
#              STATE__         COUNTY      BGN_RANGE      END_RANGE  \
# count  901808.000000  901808.000000  901808.000000  901808.000000
# mean       31.201395     100.677085       1.484405       0.986588
# std        16.569577     107.287175       5.482727       3.374599
# min         1.000000       0.000000       0.000000       0.000000
# 25%        19.000000      31.000000       0.000000       0.000000
# 50%        30.000000      75.000000       0.000000       0.000000
# 75%        45.000000     131.000000       1.000000       0.000000
# max        95.000000     873.000000    3749.000000     925.000000
#
#               LENGTH      ...             LATITUDE      LONGITUDE  \
# count  901808.000000      ...        901761.000000  901808.000000
# mean        0.230254      ...          2876.501952    6943.301274
# std         4.618485      ...          1656.745342    3955.834502
# min         0.000000      ...             0.000000  -14451.000000
# ...

# %%
dffinal.columns
# Out:
# Index([u'STATE__', u'BGN_DATE', u'BGN_TIME', u'TIME_ZONE', u'COUNTY',
#        u'COUNTYNAME', u'STATE', u'EVTYPE', u'BGN_RANGE', u'BGN_AZI',
#        u'BGN_LOCATI', u'END_DATE', u'END_TIME', u'END_RANGE', u'END_AZI',
#        u'END_LOCATI', u'LENGTH', u'WIDTH', u'F', u'MAG', u'FATALITIES',
#        u'INJURIES', u'PROPDMG', u'PROPDMGEXP', u'CROPDMG', u'CROPDMGEXP',
#        u'WFO', u'STATEOFFIC', u'ZONENAMES', u'LATITUDE', u'LONGITUDE',
#        u'LATITUDE_E', u'LONGITUDE_', u'REMARKS', u'REFNUM'],
#       dtype='object')

# %%
#adding another dataframe just to store the values of mean etc.
df = dffinal.describe()

# %%
df.columns
# Out:
# Index([u'STATE__', u'COUNTY', u'BGN_RANGE', u'END_RANGE', u'LENGTH', u'WIDTH',
#        u'F', u'MAG', u'FATALITIES', u'INJURIES', u'PROPDMG', u'CROPDMG',
#        u'LATITUDE', u'LONGITUDE', u'LATITUDE_E', u'LONGITUDE_', u'REFNUM'],
#       dtype='object')

# %%
#adding a dataframe to store the 95th percentile
dffinal2 = dffinal.quantile(q=.95)
dffinal2
# Out:
# STATE__           55.00
# COUNTY           321.00
# BGN_RANGE          8.00
# END_RANGE          6.00
# LENGTH             0.10
#                 ...
# LATITUDE        4506.00
# LONGITUDE      10319.00
# LATITUDE_E      4323.00
# LONGITUDE_     10041.00
# REFNUM        857206.65
# Name: 0.95, Length: 17, dtype: float64

# %%
#removing the outliers from the main dataframe. This will not work perfectly well on this dataset
#as some values are categorical, but trying the method here anyway
dffinal3=dffinal[dffinal<dffinal2]

# %%
dffinal3.describe()
# Out:
#              STATE__         COUNTY      BGN_RANGE      END_RANGE    LENGTH  \
# count  856043.000000  856518.000000  853533.000000  850678.000000  850355.0
# mean       29.280568      81.347918       0.805942       0.372038       0.0
# std        14.295036      62.913622       1.593174       1.067572       0.0
# min         1.000000       0.000000       0.000000       0.000000       0.0
# 25%        19.000000      29.000000       0.000000       0.000000       0.0
# 50%        29.000000      71.000000       0.000000       0.000000       0.0
# 75%        40.000000     121.000000       1.000000       0.000000       0.0
# max        54.000000     319.000000       7.900000       5.900000       0.0
#
#            ...             LATITUDE      LONGITUDE    LATITUDE_E  \
# count      ...        856419.000000  856505.000000  856491.00000
# mean       ...          2782.154201    6732.546557    1289.37648
# std        ...          1646.823740    3944.047610    1762.73774
# ...

# %%
dffinal3.plot(kind = 'bar', x = 'INJURIES' , y= 'EVTYPE')
