# %% [markdown]
# #  Enlisting the steps

# %% [markdown]
# Step 1- Check for missing values
#
# Step 2- Research on feature meaning
#
# Step 3- Train/Test split
#
# Step 4- EDA
#
#         Understand the data
#
#         Understand the relationship between variables
#
#         Plotting
#
#         Correlation
#
#         Cross tab (categorical)
#
#         Chi Squared tests
#
#         Plotting y1 as a function of x1
#
#         you want a linear relationship between variables
#
# Step 5- Try and look for variables that matter by using decision trees. The feature importance tool has to be used to assess which variables are most important.
#
# Step 6- Entropy - Maximize information gain. Entropy after minus entropy before.
#
# Step 7- We sample from a sample - bootstrapping. The sample that we have is the closest thing we have to represent the data.
#
# Step 8- Randomly select a set of features to split on
#
# Step 9- The most important feature provides the most information gain and sits on the top
#
# Step 10- Importance does not mean significant
#
# Step 11- Regularization also aids differentiating between features that matter and features that don't.
#
# OLS + Lambda(B1 + B2)
#
# Take the polynomials and then apply regularization on it. Here, the model will take all the variables and then will slowly drive them to zero.
#
# Step 12- Yet to try the polynomial method for feature selection.

# %%
import os
import pandas as pd

pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)
pd.set_option('display.notebook_repr_html', True)

df2 = pd.read_csv('dataset-energy-efficiency.csv')

import os

import math

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 20)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import os

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 20)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn import preprocessing, linear_model, model_selection, metrics

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

df, dfTest = train_test_split(df2, test_size = 0.5)

# %%
dfTest.shape
# Out:
# (384, 10)

# %%
df.shape
# Out:
# (384, 10)

# %%
df.columns
# Out:
# Index([u'RC', u'SA', u'WA', u'RA', u'OH', u'OR', u'GA', u'GAD', u'HL', u'CL'], dtype='object')

# %%
df.corr()
# Out:
#            RC        SA        WA        RA        OH        OR        GA  \
# RC   1.000000 -0.991989 -0.201137 -0.875311  0.828565  0.032857  0.056845
# SA  -0.991989  1.000000  0.195835  0.885660 -0.858159 -0.039767 -0.056326
# WA  -0.201137  0.195835  1.000000 -0.281901  0.279947  0.076613 -0.014049
# RA  -0.875311  0.885660 -0.281901  1.000000 -0.972168 -0.075184 -0.048456
# OH   0.828565 -0.858159  0.279947 -0.972168  1.000000  0.075131  0.038941
# OR   0.032857 -0.039767  0.076613 -0.075184  0.075131  1.000000 -0.036167
# GA   0.056845 -0.056326 -0.014049 -0.048456  0.038941 -0.036167  1.000000
# GAD  0.026634 -0.029127 -0.012892 -0.022393  0.028527  0.010940  0.203601
# HL   0.631248 -0.664748  0.446372 -0.861740  0.889937  0.075025  0.303427
# CL   0.636524 -0.673671  0.426362 -0.860995  0.896907  0.096794  0.239509
#
#           GAD        HL        CL
# RC   0.026634  0.631248  0.636524
# SA  -0.029127 -0.664748 -0.673671
# WA  -0.012892  0.446372  0.426362
# ...

# %%
#Building a decision tree classifier with a gini index
#Site referenced http://dataaspirant.com/2017/02/01/decision-tree-algorithm-python-with-scikit-learn/

import numpy as np
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("fivethirtyeight")
from IPython.display import Image
from sklearn.cross_validation import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report, roc_auc_score, roc_curve
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.datasets import make_classification;

import os

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 20)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn import linear_model

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import seaborn as sns

# %%
df.columns
# Out:
# Index([u'RC', u'SA', u'WA', u'RA', u'OH', u'OR', u'GA', u'GAD', u'HL', u'CL'], dtype='object')

# %%
#Finding correlated variables- Checking the relationship between surface area
#wall area and roof area
df['y'] = df.SA
df['x1'] = df.WA
df['x2'] = df.RA
# Out:
# /Users/issingh/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/issingh/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/issingh/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
model = smf.ols(formula = 'y ~ x1 + x2', data = df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.649e+31
# Date:                Mon, 21 Aug 2017   Prob (F-statistic):               0.00
# Time:                        20:28:03   Log-Likelihood:                 10677.
# No. Observations:                 384   AIC:                        -2.135e+04
# Df Residuals:                     381   BIC:                        -2.134e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.974e-14   1.01e-13      0.493      0.622   -1.49e-13    2.48e-13
# ...

# %%
#Glazing area distribution seems like some kind of a categorical variable
df['GAD'].unique()
# Out:
# array([1, 5, 2, 0, 3, 4])

# %%
#changing the names of the variables so that
#writing equations is easier
df['y'] = df.SA
df['x1'] = df.WA
df['x2'] = df.RA
df['x3'] = df.GA
df['x4'] = df.OH
df['x5'] = df.RC
df['WidthofRoom'] = df.WA/df.OH
df['LengthofRoom'] = df.RA/df.x5
df['OverallHeight'] = df.OH
df['Volume'] = df.WidthofRoom*df.LengthofRoom*df.OverallHeight
df['GAsqr'] = df.GA*df.GA
df['OverallHeightsqr'] = df.OverallHeight*df.OverallHeight
df['LengthofRoomsqr'] = df.LengthofRoom*df.LengthofRoom
df['WidthofRoomsqr'] = df.WidthofRoom*df.WidthofRoom
# Out:
# /Users/issingh/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/issingh/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/issingh/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
#From the model it seems like the glazing area is the area from which we lose/gain heat
#glazing area is the area that is leading to loss of energy
#if glazing area was not there, air conditioning would not be needed
#Glazing area represents a window

# %%
#relative compactness and surface area have an almost perfect relationship
model = smf.ols(formula = 'x5 ~ SA', data = df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     x5   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                 2.356e+04
# Date:                Mon, 21 Aug 2017   Prob (F-statistic):               0.00
# Time:                        20:28:06   Log-Likelihood:                 1105.8
# No. Observations:                 384   AIC:                            -2208.
# Df Residuals:                     382   BIC:                            -2200.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.5703      0.005    297.240      0.000       1.560       1.581
# ...

# %%
#rmodeling out the heating area
model = smf.ols(formula = 'HL ~ RC + GA + OverallHeight + LengthofRoom', data = df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HL   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     981.3
# Date:                Mon, 21 Aug 2017   Prob (F-statistic):          1.87e-198
# Time:                        20:28:07   Log-Likelihood:                -966.49
# No. Observations:                 384   AIC:                             1943.
# Df Residuals:                     379   BIC:                             1963.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
#rmodeling out the heating area
XTrain = df[['RC','GA','OverallHeight','WidthofRoom','LengthofRoom']]
model = smf.ols(formula = 'CL ~ RC + GA + OverallHeight + WidthofRoom + LengthofRoom ', data = df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     CL   R-squared:                       0.891
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     617.0
# Date:                Mon, 21 Aug 2017   Prob (F-statistic):          2.54e-179
# Time:                        20:53:22   Log-Likelihood:                -983.82
# No. Observations:                 384   AIC:                             1980.
# Df Residuals:                     378   BIC:                             2003.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
#changing the names of the variables so that
#writing equations is easier
dfTest['y'] = dfTest.SA
dfTest['x1'] = dfTest.WA
dfTest['x2'] = dfTest.RA
dfTest['x3'] = dfTest.GA
dfTest['x4'] = dfTest.OH
dfTest['x5'] = dfTest.RC
dfTest['WidthofRoom'] = dfTest.WA/dfTest.OH
dfTest['LengthofRoom'] = dfTest.RA/dfTest.x5
dfTest['OverallHeight'] = dfTest.OH
dfTest['Volume'] = dfTest.WidthofRoom*dfTest.LengthofRoom*dfTest.OverallHeight
dfTest['GAsqr'] = dfTest.GA*dfTest.GA
dfTest['OverallHeightsqr'] = dfTest.OverallHeight*dfTest.OverallHeight
dfTest['LengthofRoomsqr'] = dfTest.LengthofRoom*dfTest.LengthofRoom
dfTest['WidthofRoomsqr'] = dfTest.WidthofRoom*dfTest.WidthofRoom


Xtest = dfTest[['RC','GA','OverallHeight','WidthofRoom','LengthofRoom']]
Ytest = dfTest.CL
# Out:
# /Users/issingh/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/issingh/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/issingh/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
y_hat = model.predict(Xtest)
y = Ytest
k=1 - sum((y - y_hat) ** 2) / sum((y - y.mean()) ** 2)

# %%
print "The accuracy of the model is"  
print k
# Out:
# The accuracy of the model is
# 0.884193491247

# %%
class RidgePolynomial(object):
    def __init__(self, alpha, n):
        self.features = preprocessing.PolynomialFeatures(n)
        self.model = linear_model.Ridge(alpha)

    def fit(self, X, y):
        self.X = X
        self.features.fit(X)

        X = self.features.transform(X)
        self.model.fit(X, y)

        return self

    def predict(self, X):
        X = self.features.transform(X)
        return self.model.predict(X)

    def score(self, X, y):
        X = self.features.transform(X)
        return self.model.score(X, y)

    def mean_squared_error(self, X, y):
        y_hat = self.predict(X)
        return metrics.mean_squared_error(y_hat, y)

    def complexity(self):
        return np.sqrt(np.sum((self.model.coef_) ** 2))

# %%
alphas = [1e-1, 1e-2, 1e-3, 1e-5, 1e-7, 1e-9, 1e-11]

models = [RidgePolynomial(alpha, 17).fit(XTrain, df.CL) for alpha in alphas]
# Out:
# /Users/issingh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "

# %%
model_df = pd.DataFrame({'alpha': alphas, 'model': models})
model_df['R^2 (train)'] = model_df.model.apply(lambda model: model.score(XTrain, df.CL))
model_df['R^2 (test)'] = model_df.model.apply(lambda model: model.score(Xtest, Ytest))
model_df['Complexity'] = model_df.model.apply(lambda model: model.complexity())

model_df.drop('model', axis = 1).set_index('alpha')
# Out:
#               R^2 (train)  R^2 (test)    Complexity
# alpha
# 1.000000e-01     0.856408    0.850959  1.532404e-36
# 1.000000e-02     0.856408    0.850959  1.532404e-36
# 1.000000e-03     0.856408    0.850959  1.532404e-36
# 1.000000e-05     0.856408    0.850959  1.532404e-36
# 1.000000e-07     0.856408    0.850959  1.532404e-36
# 1.000000e-09     0.856408    0.850959  1.532404e-36
# 1.000000e-11     0.856408    0.850959  1.532404e-36

# %%
models[-1].model.coef_
# Out:
# array([  0.00000000e+00,  -5.01994292e-74,   1.38587147e-74, ...,
#          1.55817466e-38,  -5.50209017e-39,  -1.66818048e-39])
